# %%
import os
from pathlib import Path

output_dir = Path(os.environ.get("OUTPUT_DATA_DIR", "../output_data")).resolve()

# e.g., plot and save figure
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv(output_dir / "simulation_output.csv")
plt.scatter(df["id"], df["value"])
plt.savefig(output_dir / "scatter.png")
print(f"✅ Saved scatterplot to {output_dir}/scatter.png")
# Out:
# ✅ Saved scatterplot to /home/pbellec/git/airoh-mini/output_data/scatter.png
